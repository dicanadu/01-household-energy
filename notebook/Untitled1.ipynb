# %%
from google.cloud import bigquery

# %%
gbq_api = {
  "type": "service_account",
  "project_id": "wagon-bootcamp-401514",
  "private_key_id": "ed3cd174bd20958a93117498c8e9165c37a35369",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "bg-example@wagon-bootcamp-401514.iam.gserviceaccount.com",
  "client_id": "102816860579402915141",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/bg-example%40wagon-bootcamp-401514.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# %%
gbq_api["private_key"]
# Out:
# '-----BEGIN PRIVATE KEY-----\\n9hcDIRANgnmIIYkGoFoFHnW9LQKBgQC9LEE4se1Es2HW
# ...

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# Set your project ID, dataset, and table
PROJECT = "wagon-bootcamp-401514"
DATASET = "01_household_energy"
TABLE = "recs2020"
LOCATION = "EU"

# Path to your service account key file (JSON)
KEY_PATH = "wagon-bootcamp-401514-ed3cd174bd20.json"

# Create credentials from the service account key file
credentials = service_account.Credentials.from_service_account_file(KEY_PATH, scopes=["https://www.googleapis.com/auth/cloud-platform"])

# Create a BigQuery client using the credentials
client = bigquery.Client(credentials=credentials, project=PROJECT, location=LOCATION)

# Your SQL query
query = f"""
    SELECT *
    FROM `{PROJECT}.{DATASET}.{TABLE}`
"""

# Execute the query
query_job = client.query(query)
result = query_job.result()

# Process the result as needed
df = result.to_dataframe()

# %%
df.head()
# Out:
#     DOEID REGIONC            DIVISION  STATE_FIPS state_postal  state_name  \
# 0  100001    WEST      Mountain South          35           NM  New Mexico
# 1  100012   SOUTH  West South Central          48           TX       Texas
# 2  100019   SOUTH  West South Central           5           AR    Arkansas
# 3  100036   SOUTH  West South Central          40           OK    Oklahoma
# 4  100053   SOUTH      South Atlantic          24           MD    Maryland
#
#     BA_climate IECC_climate_code UATYP10  HDD65  ...  TOTALBTUWTH  \
# 0    Mixed-Dry                4B       U   3844  ...     21241.34
# 1      Hot-Dry                3B       U   2148  ...      8774.40
# 2  Mixed-Humid                3A       U   3078  ...      6097.55
# 3  Mixed-Humid                3A       U   3137  ...      3852.27
# 4  Mixed-Humid                4A       U   3776  ...      3118.09
#
#    TOTALDOLWTH  TOTALBTUOTH  TOTALDOLOTH   TOTALBTU  TOTALDOL  DBT1  DBT99  \
# ...

# %%
from google.cloud import bigquery

PROJECT = "wagon-bootcamp-401514"
DATASET = "01_household_energy"
TABLE = "recs2020"
#MY_PROJECT = "melodic-arcadia-401515"
LOCATION = "EU"


query = f"""
    SELECT *
    FROM `{PROJECT}.{DATASET}.{TABLE}`
    """

client = bigquery.Client()
query_job = client.query(query)
result = query_job.result()
df = result.to_dataframe()

# %%
df.head()
# Out:
#     DOEID REGIONC            DIVISION  STATE_FIPS state_postal  state_name  \
# 0  100001    WEST      Mountain South          35           NM  New Mexico
# 1  100012   SOUTH  West South Central          48           TX       Texas
# 2  100019   SOUTH  West South Central           5           AR    Arkansas
# 3  100036   SOUTH  West South Central          40           OK    Oklahoma
# 4  100053   SOUTH      South Atlantic          24           MD    Maryland
#
#     BA_climate IECC_climate_code UATYP10  HDD65  ...  TOTALBTUWTH  \
# 0    Mixed-Dry                4B       U   3844  ...     21241.34
# 1      Hot-Dry                3B       U   2148  ...      8774.40
# 2  Mixed-Humid                3A       U   3078  ...      6097.55
# 3  Mixed-Humid                3A       U   3137  ...      3852.27
# 4  Mixed-Humid                4A       U   3776  ...      3118.09
#
#    TOTALDOLWTH  TOTALBTUOTH  TOTALDOLOTH   TOTALBTU  TOTALDOL  DBT1  DBT99  \
# ...

# %%
features = ['TYPEHUQ', 'STORIES', 'YEARMADERANGE', 'WALLTYPE', 'ROOFTYPE', 'WINDOWS', 'SWIMPOOL', 'DISHWASH', 'CWASHER', 'DRYER', 'TELLWORK', 'TELLDAYS', 'HEATHOME', 'EQUIPM', 'NUMPORTEL', 'AIRCOND', 'NUMPORTAC', 'SMARTMETER', 'SOLAR', 'NCOMBATH', 'NHAFBATH', 'TOTROOMS', 'NUMFRIG', 'MICRO', 'TVCOLOR', 'DESKTOP', 'NUMLAPTOP', 'LGTIN1TO4', 'LGTIN4TO8', 'LGTINMORE8', 'NHSLDMEM', 'SQFTEST']

# %%
len(features)
# Out:
# 32

# %%
import pandas as pd

# %%
pd.options.display.width = 35

# %%
df[features]
# Out:
#        TYPEHUQ  STORIES  \
# 0            2        1
# 1            2        1
# 2            3        1
# 3            2        1
# 4            3        2
# ...        ...      ...
# 18491        5       -2
# 18492        5       -2
# 18493        5       -2
# 18494        4       -2
# 18495        5       -2
#
#        YEARMADERANGE  WALLTYPE  \
# 0                  4         1
# 1                  8         2
# 2                  4         6
# 3                  2         1
# 4                  1         1
# ...              ...       ...
# 18491              7         4
# 18492              5         2
# 18493              4         2
# 18494              3         4
# 18495              4         7
#
#        ROOFTYPE  WINDOWS  \
# 0             5        4
# 1             2        4
# 2             5        2
# 3             5        4
# 4             5        4
# ...         ...      ...
# 18491        -2        1
# 18492        -2        2
# 18493        -2        2
# ...

# %%
X = df[features]
y = df["KWH"]

# %%
X.shape
# Out:
# (18496, 32)

# %%
y.shape
# Out:
# (18496,)

# %%
X.dtypes
# Out:
# TYPEHUQ          Int64
# STORIES          Int64
# YEARMADERANGE    Int64
# WALLTYPE         Int64
# ROOFTYPE         Int64
# WINDOWS          Int64
# SWIMPOOL         Int64
# DISHWASH         Int64
# CWASHER          Int64
# DRYER            Int64
# TELLWORK         Int64
# TELLDAYS         Int64
# HEATHOME         Int64
# EQUIPM           Int64
# NUMPORTEL        Int64
# AIRCOND          Int64
# NUMPORTAC        Int64
# SMARTMETER       Int64
# SOLAR            Int64
# NCOMBATH         Int64
# NHAFBATH         Int64
# TOTROOMS         Int64
# NUMFRIG          Int64
# MICRO            Int64
# TVCOLOR          Int64
# DESKTOP          Int64
# NUMLAPTOP        Int64
# LGTIN1TO4        Int64
# LGTIN4TO8        Int64
# LGTINMORE8       Int64
# NHSLDMEM         Int64
# SQFTEST          Int64
# dtype: object

# %%
for x in X.dtypes:
    print(x)
    break
# Out:
# Int64

# %%
for x in X.columns:
    print(f"{x}: int")
# Out:
# TYPEHUQ: int
# STORIES: int
# YEARMADERANGE: int
# WALLTYPE: int
# ROOFTYPE: int
# WINDOWS: int
# SWIMPOOL: int
# DISHWASH: int
# CWASHER: int
# DRYER: int
# TELLWORK: int
# TELLDAYS: int
# HEATHOME: int
# EQUIPM: int
# NUMPORTEL: int
# AIRCOND: int
# NUMPORTAC: int
# SMARTMETER: int
# SOLAR: int
# NCOMBATH: int
# NHAFBATH: int
# TOTROOMS: int
# NUMFRIG: int
# MICRO: int
# TVCOLOR: int
# DESKTOP: int
# NUMLAPTOP: int
# LGTIN1TO4: int
# LGTIN4TO8: int
# LGTINMORE8: int
# NHSLDMEM: int
# SQFTEST: int

# %%
x_list = [f"{x}: int" for x in X.columns]
x_list
# Out:
# ['TYPEHUQ: int',
#  'STORIES: int',
#  'YEARMADERANGE: int',
#  'WALLTYPE: int',
#  'ROOFTYPE: int',
#  'WINDOWS: int',
#  'SWIMPOOL: int',
#  'DISHWASH: int',
#  'CWASHER: int',
#  'DRYER: int',
#  'TELLWORK: int',
#  'TELLDAYS: int',
#  'HEATHOME: int',
#  'EQUIPM: int',
#  'NUMPORTEL: int',
#  'AIRCOND: int',
#  'NUMPORTAC: int',
#  'SMARTMETER: int',
#  'SOLAR: int',
#  'NCOMBATH: int',
#  'NHAFBATH: int',
#  'TOTROOMS: int',
#  'NUMFRIG: int',
#  'MICRO: int',
#  'TVCOLOR: int',
#  'DESKTOP: int',
#  'NUMLAPTOP: int',
#  'LGTIN1TO4: int',
#  'LGTIN4TO8: int',
#  'LGTINMORE8: int',
#  'NHSLDMEM: int',
#  'SQFTEST: int']

# %%
new_x_list = ", ".join(x_list)

# %%
new_x_list
# Out:
# 'TYPEHUQ: int, STORIES: int, YEARMADERANGE: int, WALLTYPE: int, ROOFTYPE: int, WINDOWS: int, SWIMPOOL: int, DISHWASH: int, CWASHER: int, DRYER: int, TELLWORK: int, TELLDAYS: int, HEATHOME: int, EQUIPM: int, NUMPORTEL: int, AIRCOND: int, NUMPORTAC: int, SMARTMETER: int, SOLAR: int, NCOMBATH: int, NHAFBATH: int, TOTROOMS: int, NUMFRIG: int, MICRO: int, TVCOLOR: int, DESKTOP: int, NUMLAPTOP: int, LGTIN1TO4: int, LGTIN4TO8: int, LGTINMORE8: int, NHSLDMEM: int, SQFTEST: int'
